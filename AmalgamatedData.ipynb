# %%
# !pip install statsmodels==0.14.0
# Out:
# Requirement already satisfied: statsmodels==0.14.0 in /root/venv/lib/python3.9/site-packages (0.14.0)
# Requirement already satisfied: packaging>=21.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from statsmodels==0.14.0) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /root/venv/lib/python3.9/site-packages (from statsmodels==0.14.0) (0.5.4)
# Requirement already satisfied: pandas>=1.0 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.0) (1.2.5)
# Requirement already satisfied: scipy!=1.9.2,>=1.4 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.0) (1.9.3)
# Requirement already satisfied: numpy>=1.18 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from statsmodels==0.14.0) (1.23.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from packaging>=21.3->statsmodels==0.14.0) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /shared-libs/python3.9/py/lib/python3.9/site-packages (from pandas>=1.0->statsmodels==0.14.0) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from pandas>=1.0->statsmodels==0.14.0) (2.8.2)
# Requirement already satisfied: six in /shared-libs/python3.9/py-core/lib/python3.9/site-packages (from patsy>=0.5.2->statsmodels==0.14.0) (1.16.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm

# %%
#og reg
df = pd.read_csv('../work/HSRA Research Sheets - Unified Databases.csv')

df = df.drop(df[df['PType'] == 'WD'].index)

#df = df.drop(df[df['PType'] == 'NS'].index)
#df = df.drop(df[df['PType'] == 'MS'].index)
#df = df.drop(df[df['PType'] == 'P'].index)

df = df.drop(df[df['PType'] == 'GX'].index)
df = df.drop(df[df['PType'] == 'GC'].index)
df = df.drop(df[df['PType'] == 'SC'].index)
df = df.drop(df[df['PType'] == 'GSC'].index)

df['density']=(df['Mass(Kg)'])/((df['Radius(m)']**3)*(4/3)*math.pi)
df['radius']=df['Radius(m)']*100
df['density']=df['density']*0.001
df['density'] = np.log10(df['density'])
df['radius'] = np.log10(df['radius'])

mean = np.mean(df['density']/df['radius'])
median = np.median(df['density']/df['radius'])
standdev = np.std(df['density']/df['radius'])

plt.scatter(df['radius'], df['density'], s=5)
plt.xlabel('Log (Radius in $m$)')
plt.ylabel('Log (Density in $kg/m^3$)')


z = np.polyfit(df['radius'], df['density'], 1)
p = np.poly1d(z)
plt.plot(df['radius'], p(df['radius']), color='r', label='Trend Line')

axes = plt.gca()
x_vals = np.array(axes.get_xlim())
y_vals = 15.19 + -1.7 * x_vals
plt.plot(x_vals, y_vals, '--')



#plt.scatter([np.log10(4.44654332211e26)], [np.log10(4.0732e-28)], s = 20, color = "orange", label="Universe Estimate")
y_pred = p(df['radius'])
y_mean = np.mean(df['density'])
ss_total = np.sum((df['density'] - y_mean) ** 2)
ss_residual = np.sum((df['density'] - y_pred) ** 2)
r_squared = np.round(1 - (ss_residual / ss_total), 3)
plt.legend(["$R^2$ : " +str(r_squared), 'Trend Line', "De Vaucouleurs' Line", 'Estimated Values for the Universe'])
plt.show()

print(p)
print(mean)
print(median)
print(standdev)
# Out:
#
# -1.057 x + 10.55
# 0.009611862106760623
# -0.0018704766405100994
# 0.1567135429103457

# %%
#New reg all
df = pd.read_csv('../work/HSRA Research Sheets - Unified Databases.csv')

df.drop(df[df['PType'] == "WD"].index, inplace=True)

df['density'] = np.log10(df['Mass(Kg)'] / ((df['Radius(m)'] ** 3) * (4/3) * math.pi))
df['radius'] = np.log10(df['Radius(m)'])

plt.scatter(df['radius'], df['density'], s=5)
plt.xlabel('Log Radius in m')
plt.ylabel('Log Density in kg/m^3')

X_linear = sm.add_constant(df['radius'])
model_linear = sm.OLS(df['density'], X_linear).fit()

plt.plot(df['radius'], model_linear.predict(), color='r', label='Trend Line (Linear)')

plt.scatter([np.log10(4.44654332211e26)], [np.log10(4.0732e-28)], s=30, color="orange")

plt.show()

print("Linear Regression:")
f_statistic_linear = model_linear.fvalue
p_value_linear = model_linear.f_pvalue
degrees_of_freedom_linear = model_linear.df_model, model_linear.df_resid
effect_size_linear = model_linear.params['radius']

print("Linear Regression Statistics:")
print(f"F-statistic: {f_statistic_linear:.4f}")
print(f"P-value: {p_value_linear:.4e}")
print(f"Degrees of Freedom (Model, Residual): {degrees_of_freedom_linear}")
print(f"Estimated Effect Size (Coefficient for 'radius'): {effect_size_linear:.4f}")

print("\nLine Equation:")
print(f"Log(Density) =  {model_linear.params['radius']:.4f} * Log(Radius)+{model_linear.params['const']:.4f}")
# Out:
# Linear Regression:
# Linear Regression Statistics:
# F-statistic: 418292.4068
# P-value: 0.0000e+00
# Degrees of Freedom (Model, Residual): (1.0, 6190.0)
# Estimated Effect Size (Coefficient for 'radius'): -2.1027
#
# Line Equation:
# Log(Density) =  -2.1027 * Log(Radius)+19.3405

# %%
df = pd.read_csv('../work/HSRA Research Sheets - Galaxies.csv')

df['density']=((10**df['logM26'])*1.989e+30)/((((df['a26']/2)*3.086e+19)**3)*(4/3)*math.pi)

df['density'] = np.log10(df['density'])

df['radius'] = np.log10((df['a26']/2)*3.086e+19)

plt.scatter(df['radius'], df['density'], s=5)
plt.xlabel('Log Radius in m')
plt.ylabel('Log Density in kg/m^3')

X_linear = sm.add_constant(df['radius'])
model_linear = sm.OLS(df['density'], X_linear).fit()

plt.plot(df['radius'], model_linear.predict(), color='r', label='Trend Line (Linear)')

plt.scatter([np.log10(4.44654332211e26)], [np.log10(4.0732e-28)], s=30, color="orange")

plt.show()

print("Linear Regression:")
f_statistic_linear = model_linear.fvalue
p_value_linear = model_linear.f_pvalue
degrees_of_freedom_linear = model_linear.df_model, model_linear.df_resid
effect_size_linear = model_linear.params['radius']

print("Linear Regression Statistics:")
print(f"F-statistic: {f_statistic_linear:.4f}")
print(f"P-value: {p_value_linear:.4e}")
print(f"Degrees of Freedom (Model, Residual): {degrees_of_freedom_linear}")
print(f"Estimated Effect Size (Coefficient for 'radius'): {effect_size_linear:.4f}")

print("\nLine Equation:")
print(f"Log(Density) =  {model_linear.params['radius']:.4f} * Log(Radius)+{model_linear.params['const']:.4f}")
# Out:
# Linear Regression:
# Linear Regression Statistics:
# F-statistic: 124.5201
# P-value: 5.7023e-27
# Degrees of Freedom (Model, Residual): (1.0, 798.0)
# Estimated Effect Size (Coefficient for 'radius'): -0.4816
#
# Line Equation:
# Log(Density) =  -0.4816 * Log(Radius)+-11.7172

# %%
def calculate_stats(df):
    grouped = df.groupby('PType')
    result = grouped.agg({'Mass(Kg)': ['count', 'mean'], 'Radius(m)': 'mean'})
    print(result)

calculate_stats(df)

df['logMass'] = np.log10(df['Mass(Kg)'])
plt.scatter(df['logMass'], df['density'], s=5)
plt.xlabel('Log Mass in kg')
plt.ylabel('Log Density in kg/m^3')


z = np.polyfit(df['logMass'], df['density'], 1)
p = np.poly1d(z)
plt.plot(df['logMass'], p(df['logMass']), color='r', label='Trend Line')
plt.scatter([np.log10(4.44654332211e26)], [np.log10(4.0732e-28)], s = 20, color = "red")
y_pred = p(df['logMass'])
y_mean = np.mean(df['density'])
ss_total = np.sum((df['density'] - y_mean) ** 2)
ss_residual = np.sum((df['density'] - y_pred) ** 2)
r_squared = 1 - (ss_residual / ss_total)
print("R-Squared :" +str(r_squared))
plt.show()

print(p)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [6], line 6
#       3     result = grouped.agg({'Mass(Kg)': ['count', 'mean'], 'Radius(m)': 'mean'})
#       4     print(result)
# ----> 6 calculate_stats(df)
#       8 df['logMass'] = np.log10(df['Mass(Kg)'])
#       9 plt.scatter(df['logMass'], df['density'], s=5)
#
# Cell In [6], line 2, in calculate_stats(df)
#       1 def calculate_stats(df):
# ----> 2     grouped = df.groupby('PType')
#       3     result = grouped.agg({'Mass(Kg)': ['count', 'mean'], 'Radius(m)': 'mean'})
#       4     print(result)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/frame.py:6717, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6714     raise TypeError("You have to supply one of 'by' and 'level'")
#    6715 axis = self._get_axis_number(axis)
# -> 6717 return DataFrameGroupBy(
#    6718     obj=self,
#    6719     keys=by,
#    6720     axis=axis,
#    6721     level=level,
#    6722     as_index=as_index,
#    6723     sort=sort,
#    6724     group_keys=group_keys,
#    6725     squeeze=squeeze,
#    6726     observed=observed,
#    6727     dropna=dropna,
#    6728 )
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:560, in BaseGroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     557 if grouper is None:
#     558     from pandas.core.groupby.grouper import get_grouper
# --> 560     grouper, exclusions, obj = get_grouper(
#     561         obj,
#     562         keys,
#     563         axis=axis,
#     564         level=level,
#     565         sort=sort,
#     566         observed=observed,
#     567         mutated=self.mutated,
#     568         dropna=self.dropna,
#     569     )
#     571 self.obj = obj
#     572 self.axis = obj._get_axis_number(axis)
#
# File /shared-libs/python3.9/py/lib/python3.9/site-packages/pandas/core/groupby/grouper.py:811, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     809         in_axis, name, level, gpr = False, None, gpr, None
#     810     else:
# --> 811         raise KeyError(gpr)
#     812 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     813     # Add key to exclusions
#     814     exclusions.add(gpr.key)
#
# KeyError: 'PType'

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=fdc13804-8e9e-42b5-b07c-64788a4e4ff3' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
